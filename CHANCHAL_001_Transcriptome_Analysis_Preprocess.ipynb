# %%
import numpy as np
import pandas as pd

# %%
PATH = 'G:/Kountay Dwivedi/Chanchal Ma\'am/coadread_tcga_pan_can_atlas_2018/'

# %%
df_rna = pd.read_csv(PATH+'data_mrna_seq_v2_rsem_zscores_ref_all_samples.txt', sep='\t')
df_survival = pd.read_csv(PATH+'data_clinical_patient.txt', sep='\t')

# %%
df_survival=df_survival[4:]

# %%
df_survival_new = df_survival[['#Patient Identifier', 'Overall Survival (Months)', 'Disease Free (Months)']]

# %%
df_survival_new
# Out:
#     #Patient Identifier Overall Survival (Months) Disease Free (Months)
# 4          TCGA-3L-AA1B               15.61626722           15.61626722
# 5          TCGA-4N-A93T               4.799947398                   NaN
# 6          TCGA-4T-AA8H               12.65739554           12.65739554
# 7          TCGA-5M-AAT4                1.61094125                   NaN
# 8          TCGA-5M-AAT6               9.534142092                   NaN
# ..                  ...                       ...                   ...
# 593        TCGA-F5-6814               37.18315416           37.18315416
# 594        TCGA-F5-6861               38.13656837           38.13656837
# 595        TCGA-F5-6863               11.86836309                   NaN
# 596        TCGA-F5-6864               12.46013742           12.46013742
# 597        TCGA-G5-6641               26.43258704                   NaN
#
# [594 rows x 3 columns]

# %%
df_survival_new.to_csv(PATH+'survival.csv')

# %%
df=df_rna

# %%
gene_names = df['Hugo_Symbol'].values

# %%
gene_names
# Out:
# array([nan, nan, 'UBE2Q2P2', ..., 'ZYX', 'ZZEF1', 'ZZZ3'], dtype=object)

# %%
df_2018 = pd.read_csv(PATH+'Maam_DE_2018_significant.csv')

# %%
genes_2018 = df_2018['Gene name'].values

# %%
len(genes_2018)
# Out:
# 454

# %%
intersected_genes_2018 = list(set(gene_names) & set(genes_2018))

# %%
len(intersected_genes_2018)
# Out:
# 317

# %%
df_2020 = pd.read_csv(PATH+'Maam_DE_2020_significant.csv')

# %%
genes_2020 = df_2020['Annotation'].unique()

# %%
len(genes_2020)
# Out:
# 1062

# %%
intersected_genes_2020 = list(set(genes_2020) & set(gene_names))

# %%
len(intersected_genes_2020)
# Out:
# 942

# %%
df
# Out:
#       Hugo_Symbol  Entrez_Gene_Id  TCGA-3L-AA1B-01  TCGA-4N-A93T-01  \
# 0             NaN       100130426           0.6688          -6.9152
# 1             NaN       100133144           0.9244          -1.0806
# 2        UBE2Q2P2       100134869           0.8261          -0.9395
# 3         HMGB1P1           10357          -1.1189          -1.1424
# 4             NaN           10431          -0.7051           0.7349
# ...           ...             ...              ...              ...
# 20526      ZYG11A          440590           1.2642          -0.6742
# 20527      ZYG11B           79699          -0.1583          -1.8074
# 20528         ZYX            7791           0.7335          -0.0129
# 20529       ZZEF1           23140           0.3081           0.0726
# 20530        ZZZ3           26009           0.6221          -1.9346
#
#        TCGA-4T-AA8H-01  TCGA-5M-AAT4-01  TCGA-5M-AAT5-01  TCGA-5M-AAT6-01  \
# 0              -6.9152          -6.9152          -6.9152          -6.9152
# ...

# %%
df.drop(columns=['Entrez_Gene_Id'], inplace=True)

# %%
df=df.T

# %%
header = df.iloc[0]

# %%
df = df[1:]

# %%
df.columns=header

# %%
df
# Out:
# Hugo_Symbol         NaN     NaN UBE2Q2P2 HMGB1P1     NaN  NaN     NaN  \
# TCGA-3L-AA1B-01  0.6688  0.9244   0.8261 -1.1189 -0.7051  NaN  1.7005
# TCGA-4N-A93T-01 -6.9152 -1.0806  -0.9395 -1.1424  0.7349  NaN  1.9828
# TCGA-4T-AA8H-01 -6.9152  0.0307   0.3535 -1.1351 -0.2417  NaN  0.9752
# TCGA-5M-AAT4-01 -6.9152 -0.2896   1.0773  -1.095  0.9967  NaN  1.4423
# TCGA-5M-AAT5-01 -6.9152   0.343   1.2331  0.0452  1.0473  NaN  0.9238
# ...                 ...     ...      ...     ...     ...  ...     ...
# TCGA-AG-A026-01     NaN  0.8275   1.3278  0.2378 -0.0251  NaN  1.0512
# TCGA-AG-A02G-01     NaN  0.6478   1.1287  0.7063 -0.4308  NaN  1.6934
# TCGA-AG-A02N-01     NaN  1.0372  -1.4347  0.5122 -0.2245  NaN -0.2614
# TCGA-AG-A02X-01     NaN   0.168  -0.5981  0.7308 -1.1409  NaN  0.0893
# TCGA-AG-A032-01     NaN -0.4366    0.628  0.9118 -0.5786  NaN   1.054
#
# Hugo_Symbol     RNU12-2P   SSX9P  NaN  ...  ZWILCH   ZWINT    ZXDA    ZXDB  \
# ...

# %%
intersected_df = df[df.columns.intersection(intersected_genes_2020)]

# %%
intersected_df
# Out:
# Hugo_Symbol        AACS    AAK1   ABCA7   ABCC4  ABLIM2   ACACA   ACBD4  \
# TCGA-3L-AA1B-01   0.687  0.6588  -0.289  0.6993  1.1695  0.6665  0.7612
# TCGA-4N-A93T-01 -0.1351 -0.0182  1.5913 -1.3882 -0.0436  0.6841  2.2218
# TCGA-4T-AA8H-01  1.2041 -0.2947  1.9555  -1.773 -0.2891  1.0396  0.7609
# TCGA-5M-AAT4-01  0.5816  0.7478 -0.5838   0.957 -0.0121  1.8135  0.6346
# TCGA-5M-AAT5-01 -0.3284  0.6631 -0.6727  0.4328  0.3056  1.2665 -0.7247
# ...                 ...     ...     ...     ...     ...     ...     ...
# TCGA-AG-A026-01 -0.8146    0.18  1.1754  0.5319  0.3108 -0.0587  0.8147
# TCGA-AG-A02G-01   0.243 -1.3228 -0.1458  1.7418 -0.5454 -0.1394  0.5842
# TCGA-AG-A02N-01  1.2061 -0.2551 -0.9679 -1.3431 -0.3992 -0.0437 -1.1361
# TCGA-AG-A02X-01  0.3221 -2.1188   1.748  -1.702  0.3711  0.9491    -3.0
# TCGA-AG-A032-01 -0.9615  0.3738  1.3838  0.2033  1.0603   -1.32  1.1125
#
# Hugo_Symbol         ACD   ACOT9   ACSF2  ...  ZNF652  ZNF678  ZNF711  ZNF740  \
# ...

# %%
df_survival_new
# Out:
#     #Patient Identifier Overall Survival (Months) Disease Free (Months)
# 4          TCGA-3L-AA1B               15.61626722           15.61626722
# 5          TCGA-4N-A93T               4.799947398                   NaN
# 6          TCGA-4T-AA8H               12.65739554           12.65739554
# 7          TCGA-5M-AAT4                1.61094125                   NaN
# 8          TCGA-5M-AAT6               9.534142092                   NaN
# ..                  ...                       ...                   ...
# 593        TCGA-F5-6814               37.18315416           37.18315416
# 594        TCGA-F5-6861               38.13656837           38.13656837
# 595        TCGA-F5-6863               11.86836309                   NaN
# 596        TCGA-F5-6864               12.46013742           12.46013742
# 597        TCGA-G5-6641               26.43258704                   NaN
#
# [594 rows x 3 columns]

# %%
intersected_df.to_csv(PATH+'intersected_df_2020.csv')
